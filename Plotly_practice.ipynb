# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_excel('CA/prices.xlsx')

# %%
df
# Out:
#         Periods  ACICO-KW  COAST-KW  SENERGY-KW    IPG-KW  KINV-KW  KPROJ-KW  \
# 0    12/29/2017  0.238549  0.043701      0.0350  0.399000    0.114  0.301857
# 1    12/28/2017  0.238549  0.043701      0.0350  0.399000    0.114  0.301857
# 2    12/27/2017  0.237642  0.043028      0.0345  0.404000    0.113  0.282935
# 3    12/26/2017  0.231293  0.043297      0.0345  0.420000    0.114  0.274825
# 4    12/25/2017  0.230385  0.041684      0.0330  0.420000    0.115  0.267617
# ..          ...       ...       ...         ...       ...      ...       ...
# 256  01/05/2017  0.241875  0.053113      0.0365  0.355863    0.085  0.450533
# 257  01/04/2017  0.233236  0.053113      0.0345  0.355863    0.085  0.450533
# 258  01/03/2017  0.233236  0.052441      0.0340  0.355863    0.085  0.450533
# 259  01/02/2017  0.237555  0.051769      0.0340  0.355863    0.085  0.459544
# 260  12/30/2016  0.237555  0.051769      0.0345  0.355863    0.086  0.450533
#
# ...

# %%
df.columns.unique()
# Out:
# Index(['Periods', 'ACICO-KW', 'COAST-KW', 'SENERGY-KW', 'IPG-KW', 'KINV-KW',
#        'KPROJ-KW', 'KSH-KW', 'PAPER-KW', 'TAM-KW', 'MAZAYA-KW', 'ALMADINA-KW',
#        'MHC-KW', 'KBT-KW', 'ALRAI-KW', 'BCFC-BH', 'CBQK-QA', 'DEYAAR-AE',
#        'RAKBANK-AE', 'AGTHIA-AE', 'AJSS-OM', '1020-SA', '1090-SA', '4020-SA',
#        '4040-SA', '4090-SA', '6090-SA', '2340-SA', '8070-SA', '1150-SA',
#        '6001-SA', '8270-SA', 'IHG-GB', 'TT-US', 'WG-GB', 'ORWE-EG', 'DBIS-QA',
#        '1180-SA', 'DBXE-DE', 'ETISALAT-AE', 'TTE-FR', 'FIM-MT'],
#       dtype='object')

# %%
fig = px.line(df, x='Periods', y=['ACICO-KW', 'COAST-KW', 'SENERGY-KW', 'IPG-KW', 'KINV-KW',
       'KPROJ-KW', 'KSH-KW', 'PAPER-KW', 'TAM-KW', 'MAZAYA-KW', 'ALMADINA-KW',
       'MHC-KW', 'KBT-KW', 'ALRAI-KW', 'BCFC-BH', 'CBQK-QA', 'DEYAAR-AE',
       'RAKBANK-AE', 'AGTHIA-AE', 'AJSS-OM', '1020-SA', '1090-SA', '4020-SA',
       '4040-SA', '4090-SA', '6090-SA', '2340-SA', '8070-SA', '1150-SA',
       '6001-SA', '8270-SA', 'IHG-GB', 'TT-US', 'WG-GB', 'ORWE-EG', 'DBIS-QA',
       '1180-SA', 'DBXE-DE', 'ETISALAT-AE', 'TTE-FR', 'FIM-MT'])

fig.show()
